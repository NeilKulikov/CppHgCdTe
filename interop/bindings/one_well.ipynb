# %%
import numpy as np

# %%
import hgcdte_py as hgcdte

# %%
import matplotlib.pyplot as plt

# %%
xs = np.array([0.0, 10.0, 10.0001, 12.9999, 13.0, 23.0])
ys = np.array([1.0, 1.0,  0.00000, 0.00000, 1.0,  1.0])

# %%
plt.plot(xs, ys)

# %%
mod = hgcdte.model(xs, ys)

# %%
hcr = hgcdte.hcore(mod, 61)

# %%
ks2 = np.arange(0., 1.02, 0.02)

# %%
eiss2 = np.array([hcr.spectre((kx, 0.)) for kx in ks2])

# %%
plt.figure(figsize=(7.5,5), dpi=120)
plt.plot(ks2, eiss2[:, 360], 'k-')
plt.plot(ks2, eiss2[:, 362], 'y-')
plt.plot(ks2, eiss2[:, 364], 'r-')
plt.plot(ks2, eiss2[:, 366], 'g-')
plt.plot(ks2, eiss2[:, 368], 'b-')

plt.grid()

# %%
eiss2[0, 360:370:2] - eiss2[0, 364]
# Out:
# array([-0.20351188, -0.15560972,  0.        ,  0.20419175,  0.77670594])

# %%
eiss2[0:len(ks2):10, 360:370:2] - eiss2[0, 364]
# Out:
# array([[-0.20351188, -0.15560972,  0.        ,  0.20419175,  0.77670594],
#        [-0.23294237, -0.14848017, -0.02554975,  0.24905517,  0.78430442],
#        [-0.28746365, -0.15163187, -0.05589129,  0.34320658,  0.80935773],
#        [-0.3416114 , -0.1734197 , -0.06880709,  0.45190832,  0.85055024],
#        [-0.38101384, -0.20107847, -0.08127849,  0.56486158,  0.90561773],
#        [-0.40860272, -0.22675988, -0.1025654 ,  0.67836557,  0.97173814]])

# %%
ks2[0:len(ks2):10]
# Out:
# array([0. , 0.2, 0.4, 0.6, 0.8, 1. ])
