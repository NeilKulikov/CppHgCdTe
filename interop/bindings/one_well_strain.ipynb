# %%
import numpy as np

# %%
import hgcdte_py as hgcdte

# %%
import matplotlib.pyplot as plt

# %%
xs = np.array([0.0, 5., 5.0001, 8., 8.001, 25.0])
ys = np.array([0.7, 0.7,  0.1, 0.1, 0.7,  0.7])

# %%
plt.plot(xs, ys)

# %%
mod = hgcdte.model(xs, ys, bufx = 0.7)

# %%
hcr = hgcdte.hcore(mod, 61)
# Out:
# (140573945027920, 61)

# %%
ks2 = np.arange(0., 1.02, 0.02)

# %%
eiss2 = np.array([hcr.spectre((kx, 0.)) for kx in ks2])

# %%
plt.figure(figsize=(7.5,5), dpi=120)
plt.plot(ks2, eiss2[:, 360], 'k-')
plt.plot(ks2, eiss2[:, 362], 'y-')
plt.plot(ks2, eiss2[:, 364], 'r-')
plt.plot(ks2, eiss2[:, 366], 'g-')
plt.plot(ks2, eiss2[:, 368], 'b-')

plt.grid()

# %%
eiss2[0:len(ks2):10, 360:370:2] - eiss2[0, 364]
# Out:
# array([[-0.16886315, -0.12227789,  0.        ,  0.28216812,  0.73411223],
#        [-0.1888169 , -0.11612136, -0.01989643,  0.32352165,  0.75298201],
#        [-0.22493099, -0.1208774 , -0.04527218,  0.41622181,  0.80325136],
#        [-0.25826345, -0.14116871, -0.05791684,  0.52762416,  0.87211411],
#        [-0.28697664, -0.16547225, -0.07241475,  0.64551806,  0.95068185],
#        [-0.31468748, -0.19176439, -0.09582977,  0.76531876,  1.03511745]])

# %%
eiss2[10, 360] - eiss2[0, 364]
# Out:
# -0.18961623109040188
