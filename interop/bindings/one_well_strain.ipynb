# %%
import numpy as np

# %%
import hgcdte_py as hgcdte

# %%
import matplotlib.pyplot as plt

# %%
xs = np.array([0.0, 0.0001, 3., 3.0001, 20.])
ys = np.array([0.8, 0.2,   0.2,  0.8,   0.8])

# %%
plt.plot(xs, ys)

# %%
mod = hgcdte.model(xs, ys, bufx = 1.)

# %%
hcr = hgcdte.hcore(mod, 41)
# Out:
# (140636952121232, 41)

# %%
ks2 = np.arange(0., 1.02, 0.02)

# %%
eiss2 = np.array([hcr.spectre((kx, 0.)) for kx in ks2])

# %%
plt.figure(figsize=(7.5,5), dpi=120)
plt.plot(ks2, eiss2[:, 360], 'k-')
plt.plot(ks2, eiss2[:, 362], 'y-')
plt.plot(ks2, eiss2[:, 364], 'r-')
plt.plot(ks2, eiss2[:, 366], 'g-')
plt.plot(ks2, eiss2[:, 368], 'b-')

plt.grid()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-10-848d0503f978> in <module>
#       1 plt.figure(figsize=(7.5,5), dpi=120)
# ----> 2 plt.plot(ks2, eiss2[:, 360], 'k-')
#       3 plt.plot(ks2, eiss2[:, 362], 'y-')
#       4 plt.plot(ks2, eiss2[:, 364], 'r-')
#       5 plt.plot(ks2, eiss2[:, 366], 'g-')
#
# IndexError: index 360 is out of bounds for axis 1 with size 328

# %%
eiss2[0:len(ks2):10, 238:250:2] - eiss2[0, 244]
# Out:
# array([[-0.28071242, -0.16441182, -0.09973576,  0.        ,  0.43797798,
#          0.90731504],
#        [-0.28532708, -0.17966153, -0.09696376, -0.01531668,  0.47095785,
#          0.92257037],
#        [-0.29207315, -0.21231514, -0.10462318, -0.03826094,  0.55279235,
#          0.96515283],
#        [-0.30747457, -0.24666186, -0.12816617, -0.05069348,  0.65884182,
#          1.02795682],
#        [-0.33056898, -0.27685713, -0.15477115, -0.06473055,  0.77565623,
#          1.10419969],
#        [-0.36089631, -0.3051465 , -0.18206726, -0.08728491,  0.89706923,
#          1.18922556]])

# %%
eiss2[0:len(ks2):10, 360:370:2] - eiss2[0, 364]
# Out:
# array([[-0.08822344, -0.06252592,  0.        ,  0.12171321,  0.43470801],
#        [-0.12320643, -0.05441131, -0.02408301,  0.18731364,  0.45389472],
#        [-0.1512632 , -0.07141879, -0.02486489,  0.30106005,  0.5072289 ],
#        [-0.1617609 , -0.08427775, -0.03201655,  0.42437443,  0.58514402],
#        [-0.1739296 , -0.09813657, -0.052849  ,  0.55027429,  0.6782774 ],
#        [-0.1900467 , -0.11947615, -0.08603971,  0.6763311 ,  0.78007534]])

# %%
strain = hcr.strain_hinst()

# %%
strain.shape
# Out:
# (488, 488)

# %%
plt.imshow(np.real(strain), vmin = -1.e-3, vmax = 1.e-3)
