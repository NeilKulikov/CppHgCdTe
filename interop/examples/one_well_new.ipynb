# %%
import numpy as np

# %%
import hgcdte

# %%
import matplotlib.pyplot as plt

# %%
xs = np.array([0.0, 0.0001, 3., 3.0001, 20.])
ys = np.array([0.65, 0.1,   0.1,  0.65,   0.65])

# %%
plt.plot(xs, ys)

# %%
mod = hgcdte.model(xs, ys)

# %%
hcr = hgcdte.hcore(mod, 41)

# %%
ks2 = np.arange(0., 1.02, 0.02)

# %%
eiss2 = np.array([hcr.spectre((kx, 0.)) for kx in ks2])

# %%
plt.figure(figsize=(7.5,5), dpi=120)
plt.plot(ks2, eiss2[:, 246], 'k-')
plt.plot(ks2, eiss2[:, 244], 'y-')
plt.plot(ks2, eiss2[:, 240], 'r-')
plt.plot(ks2, eiss2[:, 238], 'g-')
plt.plot(ks2, eiss2[:, 236], 'b-')

plt.grid()

# %%
eiss2[0:len(ks2):10, 238:250:2] - eiss2[0, 244]
# Out:
# array([[-0.25711845, -0.16317196, -0.12144282,  0.        ,  0.2712368 ,
#          0.67660359],
#        [-0.2642674 , -0.18324207, -0.11489907, -0.02025055,  0.31429827,
#          0.7018298 ],
#        [-0.27149711, -0.21704358, -0.11943541, -0.04514343,  0.40938858,
#          0.76564186],
#        [-0.28801762, -0.24698457, -0.13869979, -0.05806798,  0.52253813,
#          0.84296664],
#        [-0.31282156, -0.27424627, -0.16229548, -0.07350443,  0.64166218,
#          0.92964898],
#        [-0.34500023, -0.30223657, -0.18863529, -0.09793465,  0.76234166,
#          1.01998299]])

# %%
eiss2[0:len(ks2):10, 238:250:2] - eiss2[0, 244]
# Out:
# array([[-0.25711845, -0.16317196, -0.12144282,  0.        ,  0.2712368 ,
#          0.67660359],
#        [-0.2642674 , -0.18324207, -0.11489907, -0.02025055,  0.31429827,
#          0.7018298 ],
#        [-0.27149711, -0.21704358, -0.11943541, -0.04514343,  0.40938858,
#          0.76564186],
#        [-0.28801762, -0.24698457, -0.13869979, -0.05806798,  0.52253813,
#          0.84296664],
#        [-0.31282156, -0.27424627, -0.16229548, -0.07350443,  0.64166218,
#          0.92964898],
#        [-0.34500023, -0.30223657, -0.18863529, -0.09793465,  0.76234166,
#          1.01998299]])

# %%
eiss2[0:len(ks2):10, 360:370:2] - eiss2[0, 364]
# Out:
# array([[-0.16916063, -0.12547504,  0.        ,  0.28209163,  0.73184441],
#        [-0.18962655, -0.11881848, -0.02009221,  0.32350987,  0.75091239],
#        [-0.22606689, -0.12294609, -0.04627355,  0.41632963,  0.80158916],
#        [-0.25955055, -0.14281974, -0.05984551,  0.52785727,  0.87080943],
#        [-0.28837067, -0.16714678, -0.07494361,  0.64587092,  0.94969482],
#        [-0.31619051, -0.19366946, -0.09878092,  0.76578102,  1.03443509]])

# %%
eiss2[0:len(ks2):10, 238:250:2] - eiss2[0, 244]
# Out:
# array([[-0.28415369, -0.16916513, -0.12540877,  0.        ,  0.28227331,
#          0.73757589],
#        [-0.29090159, -0.1895854 , -0.11879486, -0.02008376,  0.32368922,
#          0.75539763],
#        [-0.29824073, -0.22605933, -0.12292513, -0.04625527,  0.41651052,
#          0.80378914],
#        [-0.314523  , -0.25955137, -0.14278654, -0.05982388,  0.52804203,
#          0.87184832],
#        [-0.33882256, -0.28836954, -0.16710773, -0.07491825,  0.64605721,
#          0.95057182],
#        [-0.37034337, -0.31620482, -0.19363215, -0.09875103,  0.7659646 ,
#          1.03537684]])

# %%
eiss2[0:len(ks2):10, 360:370:2] - eiss2[0, 364]
# Out:
# array([[-0.16916063, -0.12547504,  0.        ,  0.28209163,  0.73184441],
#        [-0.18962655, -0.11881848, -0.02009221,  0.32350987,  0.75091239],
#        [-0.22606689, -0.12294609, -0.04627355,  0.41632963,  0.80158916],
#        [-0.25955055, -0.14281974, -0.05984551,  0.52785727,  0.87080943],
#        [-0.28837067, -0.16714678, -0.07494361,  0.64587092,  0.94969482],
#        [-0.31619051, -0.19366946, -0.09878092,  0.76578102,  1.03443509]])

# %%
eiss2[10, 360] - eiss2[0, 364]
# Out:
# -0.18961623109040188
