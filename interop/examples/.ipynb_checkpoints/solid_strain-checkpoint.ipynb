# %%
import numpy as np

# %%
import hgcdte_py as hgcdte

# %%
import matplotlib.pyplot as plt

# %%
xs = np.array([0.0, 20.])
ys = np.array([0.0, 0.0])

# %%
plt.plot(xs, ys)

# %%
mod = hgcdte.model(xs, ys, bufx = 0.7)

# %%
hcr = hgcdte.hcore(mod, 61)
# Out:
# (140239610124976, 61)

# %%
ks2 = np.arange(0., 1.02, 0.02)

# %%
eiss2 = np.array([hcr.spectre((kx, 0.)) for kx in ks2])

# %%
plt.figure(figsize=(7.5,5), dpi=120)
plt.plot(ks2, eiss2[:, 360], 'k-')
plt.plot(ks2, eiss2[:, 362], 'y-')
plt.plot(ks2, eiss2[:, 364], 'r-')
plt.plot(ks2, eiss2[:, 366], 'g-')
plt.plot(ks2, eiss2[:, 368], 'b-')

plt.grid()

# %%
eiss2[0:len(ks2):10, 360:370:2] - eiss2[0, 364]
# Out:
# array([[-0.16883096, -0.12223968,  0.        ,  0.28203369,  0.73850926],
#        [-0.18874811, -0.11611299, -0.01989786,  0.32338548,  0.75622997],
#        [-0.22490123, -0.1208693 , -0.04527563,  0.41607526,  0.80431573],
#        [-0.25825428, -0.14116012, -0.0579212 ,  0.52746457,  0.87190725],
#        [-0.28696729, -0.16547016, -0.07241627,  0.64534886,  0.95011982],
#        [-0.31468311, -0.19176818, -0.09582658,  0.76514543,  1.03446425]])

# %%
eiss2[0:len(ks2):10, 360:370:2] - eiss2[0, 364]
# Out:
# array([[-0.16883096, -0.12223968,  0.        ,  0.28203369,  0.73850926],
#        [-0.18874811, -0.11611299, -0.01989786,  0.32338548,  0.75622997],
#        [-0.22490123, -0.1208693 , -0.04527563,  0.41607526,  0.80431573],
#        [-0.25825428, -0.14116012, -0.0579212 ,  0.52746457,  0.87190725],
#        [-0.28696729, -0.16547016, -0.07241627,  0.64534886,  0.95011982],
#        [-0.31468311, -0.19176818, -0.09582658,  0.76514543,  1.03446425]])

# %%
strain = hcr.strain_hinst()

# %%
strain
# Out:
# array([[-4.30853914e-04+0.00000000e+00j,  0.00000000e+00+0.00000000e+00j,
#          0.00000000e+00+0.00000000e+00j, ...,
#          0.00000000e+00+0.00000000e+00j,  0.00000000e+00+0.00000000e+00j,
#          0.00000000e+00+0.00000000e+00j],
#        [ 0.00000000e+00+0.00000000e+00j,  0.00000000e+00+0.00000000e+00j,
#          0.00000000e+00+0.00000000e+00j, ...,
#          0.00000000e+00+0.00000000e+00j, -3.12412441e-05-3.17136775e-05j,
#          0.00000000e+00+0.00000000e+00j],
#        [ 0.00000000e+00+0.00000000e+00j,  0.00000000e+00+0.00000000e+00j,
#          0.00000000e+00+0.00000000e+00j, ...,
#          0.00000000e+00+0.00000000e+00j,  0.00000000e+00+0.00000000e+00j,
#          0.00000000e+00+0.00000000e+00j],
#        ...,
#        [ 0.00000000e+00+0.00000000e+00j,  0.00000000e+00+0.00000000e+00j,
#          3.69356894e-05+3.74063793e-05j, ...,
#          2.40513998e-05+3.37705366e-05j, -0.00000000e+00+0.00000000e+00j,
#          0.00000000e+00+0.00000000e+00j],
#        [ 5.15549170e-06+7.15173941e-06j,  0.00000000e+00+0.00000000e+00j,
#          0.00000000e+00+0.00000000e+00j, ...,
#          0.00000000e+00+0.00000000e+00j,  0.00000000e+00+0.00000000e+00j,
#          0.00000000e+00+0.00000000e+00j],
#        [-5.19749791e-07+4.00809250e-05j, -0.00000000e+00+0.00000000e+00j,
#          0.00000000e+00+0.00000000e+00j, ...,
#          0.00000000e+00+0.00000000e+00j, -1.81450819e-06+1.06826333e-05j,
#          0.00000000e+00+0.00000000e+00j]])
