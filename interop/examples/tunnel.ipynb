# %%
import numpy as np

# %%
import hgcdte_py as hgcdte

# %%
import matplotlib.pyplot as plt

# %%
xs = np.array([0.0, 10.0, 10.0001, 14.9999, 15.0, 20.0, 20.0001, 24.9999, 25.0, 35.0])
ys = np.array([0.7, 0.7,  0.1,     0.1,     0.7,  0.7,  0.1,     0.1,     0.7,  0.7])

# %%
plt.plot(xs, ys)

# %%
md = hgcdte.make_model(xs, ys)

mod = hgcdte.model(xs, ys)

# %%
mod

# %%
hc = hgcdte.make_hcore(md, 101)

hcr = hgcdte.hcore(mod, 101)

# %%
hi = hgcdte.make_hinst(hc, (0.0, 0.0))

# %%
ei = hgcdte.gen_eigen(hi)

# %%
eigs = hcr.spectre((0., 0.))

# %%
ks = np.arange(0., 0.75, 0.02)
ks2 = np.arange(0., 1., 0.02)

# %%
vf = np.vectorize(lambda kx: hcr.spectre((kx, 0.)))

# %%
eiss = np.array([hcr.spectre((kx, 0.)) for kx in ks])
eiss2 = np.array([hcr.spectre((kx, 0.)) for kx in ks2])

# %%
plt.figure(figsize=(7.5,5), dpi=120)
plt.plot(ks2, eiss2[:, 606], 'y-')
plt.plot(ks2, eiss2[:, 608], 'r-')
plt.plot(ks2, eiss2[:, 610], 'g-')
plt.plot(ks2, eiss2[:, 612], 'b-')
plt.plot(ks2, eiss2[:, 614], 'k-')
plt.grid()

# %%
eiss2[0:len(ks2):10, 600:612:2] - eiss2[0, 604]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2c87f1461573> in <module>
# ----> 1 eiss2[0:len(ks2):10, 600:612:2] - eiss2[0, 604]
#
# NameError: name 'eiss2' is not defined
